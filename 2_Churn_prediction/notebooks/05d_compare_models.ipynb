# %%
MLFLOW_TRACKING_URI = "../models/mlruns"
MLFLOW_EXPERIMENT_NAME = "churn_rate_prediction"

# %%
# Load packages
import pandas as pd

import mlflow
from mlflow.tracking import MlflowClient

# %% [markdown]
# ___
# ## Intialize Mlflow

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()

# %%
# Check if experiment exist or not
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
if not exp:
    raise Exception(
        f"Experiment '{MLFLOW_EXPERIMENT_NAME}' doesn't exist at '{MLFLOW_TRACKING_URI}'"
    )

print(exp)
# Out:
# <Experiment: artifact_location='../models/mlruns/0', experiment_id='0', lifecycle_stage='active', name='churn_rate_prediction', tags={}>

# %% [markdown]
# ___
# ## Getting runs to compare models

# %%
# Get all runs
runs = mlflow.search_runs([exp.experiment_id])
runs
# Out:
#                              run_id experiment_id    status  \
# 0  1b46bebb0cfd4e81b62dc7ba1a3f3225             0  FINISHED
# 1  7480a8fca510441dbacb5da49239e4fd             0  FINISHED
# 2  ae94b197139b45218064e9293c6cc389             0  FINISHED
# 3  3f7d30635d3047f4aa5724b832b88504             0  FINISHED
# 4  312a7b32a5a546bc8035e106f1dcd731             0  FINISHED
#
#                                         artifact_uri  \
# 0  ../models/mlruns/0/1b46bebb0cfd4e81b62dc7ba1a3...
# 1  ../models/mlruns/0/7480a8fca510441dbacb5da4923...
# 2  ../models/mlruns/0/ae94b197139b45218064e9293c6...
# 3  ../models/mlruns/0/3f7d30635d3047f4aa5724b832b...
# 4  ../models/mlruns/0/312a7b32a5a546bc8035e106f1d...
#
#                         start_time                         end_time  \
# 0 2022-07-13 12:01:28.967000+00:00 2022-07-13 12:01:29.314000+00:00
# 1 2022-07-13 12:01:26.185000+00:00 2022-07-13 12:01:26.451000+00:00
# 2 2022-07-13 12:01:23.668000+00:00 2022-07-13 12:01:23.899000+00:00
# 3 2022-07-13 12:01:14.435000+00:00 2022-07-13 12:01:14.705000+00:00
# 4 2022-07-13 11:09:55.514000+00:00 2022-07-13 11:09:55.838000+00:00
#
#    metrics.recall_score  metrics.f1_score  metrics.accuracy_score  \
# 0                 0.613             0.586                   0.765
# 1                 0.768             0.642                   0.768
# 2                 0.742             0.636                   0.769
# 3                 0.458             0.552                   0.798
# 4                 0.755             0.628                   0.757
#
#    metrics.precision_score                            tags.mlflow.source.name  \
# 0                    0.561  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
# 1                    0.552  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
# 2                    0.556  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
# 3                    0.693  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
# 4                    0.537  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
#
#                tags.mlflow.runName tags.mlflow.source.type tags.mlflow.user
# 0               XGBoost Classifier                   LOCAL            ahmed
# 1             Ada-Boost Classifier                   LOCAL            ahmed
# 2        Random Forrest Classifier                   LOCAL            ahmed
# 3    Support Vector Classifier SVC                   LOCAL            ahmed
# 4  Base Model, Logistic Regression                   LOCAL            ahmed
