# %%
MLFLOW_TRACKING_URI = "../models/mlruns"
MLFLOW_EXPERIMENT_NAME = "car_price_prediction"

# %%
# Load packages
import pandas as pd

import mlflow
from mlflow.tracking import MlflowClient

# %% [markdown]
# ___
# ## Intialize Mlflow

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()

# %%
# Check if experiment exist or not
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
if not exp:
    raise Exception(
        f"Experiment '{MLFLOW_EXPERIMENT_NAME}' doesn't exist at '{MLFLOW_TRACKING_URI}'"
    )

print(exp)
# Out:
# <Experiment: artifact_location='../models/mlruns/0', experiment_id='0', lifecycle_stage='active', name='car_price_prediction', tags={}>

# %% [markdown]
# ___
# ## Getting runs to compare models

# %%
# Get all runs
runs = mlflow.search_runs([exp.experiment_id])
runs
# Out:
#                              run_id experiment_id    status  \
# 0  1837912788004463a0ed345d701b4a38             0  FINISHED
# 1  871e33a94e9a42819d93d28209cfca7e             0  FINISHED
# 2  8951513f5d3d4b41bf2c00709d9abfc4             0  FINISHED
# 3  69473bbfc05848d083efbd74c8bfcc92             0  FINISHED
# 4  d10852341b064d9ab5b326d1afa2a311             0  FINISHED
# 5  c98dd21c560342148db29364222eafed             0  FINISHED
# 6  2728e7e97d774cefb7ed9635f2a6963e             0  FINISHED
#
#                                         artifact_uri  \
# 0  ../models/mlruns/0/1837912788004463a0ed345d701...
# 1  ../models/mlruns/0/871e33a94e9a42819d93d28209c...
# 2  ../models/mlruns/0/8951513f5d3d4b41bf2c00709d9...
# 3  ../models/mlruns/0/69473bbfc05848d083efbd74c8b...
# 4  ../models/mlruns/0/d10852341b064d9ab5b326d1afa...
# 5  ../models/mlruns/0/c98dd21c560342148db29364222...
# 6  ../models/mlruns/0/2728e7e97d774cefb7ed9635f2a...
#
# ...

# %% [markdown]
# ___
# **We can see that the Random-Forest-Regressor is the best model we have and follows it the SVR**
