# %%
DATA_PATH = "../data/processed/00_preprocessed.pkl"
EXPORT_PATH = "../data/processed/01_features.pkl"

DROP_COLS = ['customerid', 'gender', 'partner']

# %%
# Load packages
import pandas as pd

pd.options.display.max_columns=100

# %% [markdown]
# ___
# ## Read Data:

# %%
df = pd.read_pickle(DATA_PATH)

# %%
df.sample(5)
# Out:
#       customerid  gender  seniorcitizen  partner  dependents  tenure  \
# 5474  4912-piguy     0.0              0      0.0         0.0       1
# 2149  2014-mkgmh     0.0              0      0.0         0.0      46
# 4039  8161-qymtt     1.0              0      0.0         0.0       7
# 5153  5439-wikxb     1.0              1      1.0         0.0      41
# 1226  7115-irdhs     0.0              0      1.0         0.0      72
#
#       phoneservice  multiplelines  internetservice  onlinesecurity  \
# 5474           1.0            2.0              2.0             1.0
# 2149           1.0            2.0              2.0             1.0
# 4039           1.0            2.0              2.0             1.0
# 5153           1.0            1.0              2.0             1.0
# 1226           1.0            2.0              0.0             0.0
#
#       onlinebackup  deviceprotection  techsupport  streamingtv  \
# 5474           1.0               1.0          1.0          2.0
# 2149           1.0               2.0          1.0          2.0
# 4039           1.0               1.0          1.0          2.0
# 5153           2.0               1.0          1.0          2.0
# 1226           0.0               0.0          0.0          0.0
#
#       streamingmovies  contract  paperlessbilling  paymentmethod  \
# 5474              1.0       0.0               1.0            0.0
# 2149              2.0       1.0               1.0            0.0
# 4039              2.0       0.0               1.0            0.0
# 5153              2.0       0.0               1.0            0.0
# 1226              0.0       2.0               0.0            2.0
#
#       monthlycharges  totalcharges  churn
# 5474           84.60         84.60    0.0
# 2149          101.10       4674.40    0.0
# 4039           94.10        701.30    0.0
# 5153           94.55       3851.45    0.0
# 1226           24.65       1830.05    0.0

# %% [markdown]
# ___
# ## Dropping irrelevant columns:

# %%
df.drop(columns=DROP_COLS, inplace=True)

# %%
df.sample(1).iloc[0]
# Out:
# seniorcitizen          1.00
# dependents             0.00
# tenure                53.00
# phoneservice           0.00
# multiplelines          0.00
# internetservice        1.00
# onlinesecurity         1.00
# onlinebackup           2.00
# deviceprotection       2.00
# techsupport            1.00
# streamingtv            2.00
# streamingmovies        2.00
# contract               0.00
# paperlessbilling       1.00
# paymentmethod          0.00
# monthlycharges        54.45
# totalcharges        2854.55
# churn                  1.00
# Name: 2940, dtype: float64

# %% [markdown]
# ___
# ## Export data

# %%
df.to_pickle(EXPORT_PATH)
