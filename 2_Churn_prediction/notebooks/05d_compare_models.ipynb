# %%
MLFLOW_TRACKING_URI = "../models/mlruns"
MLFLOW_EXPERIMENT_NAME = "churn_rate_prediction"

# %%
# Load packages
import pandas as pd

import mlflow
from mlflow.tracking import MlflowClient

# %% [markdown]
# ___
# ## Intialize Mlflow

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()

# %%
# Check if experiment exist or not
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
if not exp:
    raise Exception(
        f"Experiment '{MLFLOW_EXPERIMENT_NAME}' doesn't exist at '{MLFLOW_TRACKING_URI}'"
    )

print(exp)
# Out:
# <Experiment: artifact_location='../models/mlruns/0', experiment_id='0', lifecycle_stage='active', name='churn_rate_prediction', tags={}>

# %% [markdown]
# ___
# ## Getting runs to compare models

# %%
# Get all runs
runs = mlflow.search_runs([exp.experiment_id])
runs
# Out:
#                              run_id experiment_id    status  \
# 0  0448e4af18294b679f998e2c6cfd4fde             0  FINISHED
# 1  cb042f8c107d4e62aea3481302246cc1             0  FINISHED
# 2  2e83fb164a9e45b08ecebd04cb10e82a             0  FINISHED
# 3  a0bb2886c0a149a9847a0392a0b2f915             0  FINISHED
# 4  542004ba756449af8f9b568038243236             0  FINISHED
#
#                                         artifact_uri  \
# 0  ../models/mlruns/0/0448e4af18294b679f998e2c6cf...
# 1  ../models/mlruns/0/cb042f8c107d4e62aea34813022...
# 2  ../models/mlruns/0/2e83fb164a9e45b08ecebd04cb1...
# 3  ../models/mlruns/0/a0bb2886c0a149a9847a0392a0b...
# 4  ../models/mlruns/0/542004ba756449af8f9b5680382...
#
#                         start_time                         end_time  \
# 0 2022-07-07 12:32:42.508000+00:00 2022-07-07 12:32:42.816000+00:00
# 1 2022-07-07 12:14:18.009000+00:00 2022-07-07 12:14:18.398000+00:00
# 2 2022-07-07 12:14:16.154000+00:00 2022-07-07 12:14:16.430000+00:00
# 3 2022-07-07 12:14:12.274000+00:00 2022-07-07 12:14:12.509000+00:00
# 4 2022-07-07 11:51:39.267000+00:00 2022-07-07 11:51:39.781000+00:00
#
#    metrics.recall_score  metrics.f1_score  metrics.accuracy_score  \
# 0                 0.447             0.541                   0.794
# 1                 0.474             0.534                   0.776
# 2                 0.474             0.561                   0.799
# 3                 0.458             0.552                   0.798
# 4                 0.766             0.629                   0.755
#
#    metrics.precision_score tags.mlflow.source.type tags.mlflow.user  \
# 0                    0.683                   LOCAL            ahmed
# 1                    0.612                   LOCAL            ahmed
# 2                    0.687                   LOCAL            ahmed
# 3                    0.693                   LOCAL            ahmed
# 4                    0.534                   LOCAL            ahmed
#
#                              tags.mlflow.source.name  \
# 0  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
# 1  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
# 2  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
# 3  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
# 4  C:\Users\ahmed\anaconda3\lib\site-packages\ipy...
#
#                tags.mlflow.runName
# 0        Random Forrest Classifier
# 1               XGBoost Classifier
# 2             Ada-Boost Classifier
# 3    Support Vector Classifier SVC
# 4  Base Model, Logistic Regression
